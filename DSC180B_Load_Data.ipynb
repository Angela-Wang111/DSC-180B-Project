# %%
pip install pydicom
# Out:
# ...
#
# ...

# %%
import pydicom as dicom
import matplotlib.pylab as plt

# specify your image path
image_path = 'dataset/dataset/0.0.19.600494.55.2.2.5.576808282067020.5480970504893.0'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array, cmap = "gray")

# %%
import pandas as pd

# %%
pd.read_csv("Pneumothorax_reports.csv")
# Out:
#                                                 filename  \
# 0      P0_04_11_2563_DICOM_00003CE3_AA5E0983_AAABDF17...
# 1      P1_04_11_2563_DICOM_00007C47_AAF286F4_AAD441BF...
# 2      P2_04_11_2563_DICOM_000092B9_AA9D0BC8_AA3EE075...
# 3      P3_04_11_2563_DICOM_0000E7C7_AA1E8FE9_AAC4FD4C...
# 4      P4_05_12_2563_DICOM_00004417_AAD0D8C4_AAD9F44D...
# ...                                                  ...
# 19635  P13741_01_04_2573_DICOM_00008271_AAC28144_AA82...
# 19636  P12478_01_02_2573_DICOM_00006761_AAF8D7A3_AA88...
# 19637  P12478_01_02_2573_DICOM_00006761_AAF8D7A3_AA88...
# 19638  P13745_03_04_2573_DICOM_0000B0F7_AA69AC7D_AAE8...
# 19639  P13745_03_04_2573_DICOM_0000B0F7_AA69AC7D_AAE8...
#
#                                           SOPInstanceUID  \
# 0      0.6.16.756977.42.5.5.0.84319505740.37071111735...
# 1      0.2.95.898927.84.7.3.8.93105928782.85706656872...
# 2      9.2.34.674100.41.6.9.5.92304504941.79045650880...
# ...

# %% [markdown]
# Kaggle: Pneumothorax challenge
# Ranlinks encoding / decoding scipts: Turn the long string of numbers back into actual pixel locations

# %% [markdown]
# Understand the DICOM format: storing medical images in the hospital
# Universal standard
# Organize images by StudyInstanceUID(person, time, date); P-value: for each patient; Date is relative to each other
# ; SOPInstanceUID
